# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("dataset_limpo_medianag.csv")

# %%
db=
# Out:
#   Cell In[3], line 1
#     db=
#        ^
# SyntaxError: invalid syntax
