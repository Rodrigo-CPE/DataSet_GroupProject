# %%
import pandas as pd

df = pd.read_csv("DATASET/dataset_limpo_medianag.csv")

# aumentar para ~100k linhas
df_grande = df.sample(n=100000, replace=True, random_state=42).copy()
df_grande.to_csv("DATASET/dataset_100k.csv", index=False)

# %%
import pandas as pd

# %%
df_test = df.sample(n=10000, replace=True)
print("OK")
